# %%
print("hello world")
# Out:
# hello world

# %%
import pandas as pd

# %%
diabetes = pd.read_csv(r'E:\糖尿病\糖尿病\diabetes.csv', na_values=['NA'])

# %%
diabetes.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes.head(150)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 145            0      102             75             23        0   0.0
# 146            9       57             80             37        0  32.8
# 147            2      106             64             35      119  30.5
# 148            5      147             78              0        0  33.7
# 149            2       90             70             17        0  27.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 145                     0.572   21        0
# 146                     0.096   41        0
# 147                     1.400   34        0
# 148                     0.218   65        0
# 149                     0.085   22        0
#
# [150 rows x 9 columns]

# %%
diabetes.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
# %matplotlib inline

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sb

# %%
sb.pairplot(diabetes.dropna(), hue='Outcome', palette="husl")

# %%
diabetes.loc[diabetes['Outcome']== 2,'Outcome'] = 1

# %%
diabetes['Outcome'].unique()
# Out:
# array([1, 0])

# %%
diabetes = diabetes.loc[(diabetes['Outcome'] != 0) & (diabetes['Pregnancies'] >= 10)]

# %%
diabetes.loc[diabetes['Outcome'] == 1, 'Pregnancies'].hist()
# Out:
# <Axes: >

# %%
diabetes = pd.read_csv(r'E:\糖尿病\糖尿病\diabetes.csv', na_values=['NA'])

# %%
diabetes.loc[(diabetes['Outcome']==0) & (diabetes['Pregnancies'] <10) ]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 10             4      110             92              0        0  37.6
# 18             1      103             30             38       83  43.3
# ..           ...      ...            ...            ...      ...   ...
# 760            2       88             58             26       16  28.4
# 762            9       89             62              0        0  22.5
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 1                       0.351   31        0
# 3                       0.167   21        0
# 5                       0.201   30        0
# 10                      0.191   30        0
# 18                      0.183   33        0
# ..                        ...  ...      ...
# 760                     0.766   22        0
# 762                     0.142   33        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 767                     0.315   23        0
#
# [472 rows x 9 columns]

# %%
diabetes.loc[diabetes['Outcome'] == 0, 'Glucose'].hist()
# Out:
# <Axes: >

# %%
diabetes.loc[diabetes['Outcome']==1, 'Glucose'].hist()
# Out:
# <Axes: >

# %%
truediabetes= diabetes.loc[diabetes['Outcome']==1]

# %%
truediabetes.mean()
# Out:
# Pregnancies                   4.865672
# Glucose                     141.257463
# BloodPressure                70.824627
# SkinThickness                22.164179
# Insulin                     100.335821
# BMI                          35.142537
# DiabetesPedigreeFunction      0.550500
# Age                          37.067164
# Outcome                       1.000000
# dtype: float64

# %%
falsediabetes= diabetes.loc[diabetes['Outcome']==0]

# %%
falsediabetes.mean()
# Out:
# Pregnancies                   3.298000
# Glucose                     109.980000
# BloodPressure                68.184000
# SkinThickness                19.664000
# Insulin                      68.792000
# BMI                          30.304200
# DiabetesPedigreeFunction      0.429734
# Age                          31.190000
# Outcome                       0.000000
# dtype: float64

# %%
diabetes.loc[(diabetes['Glucose'].isnull()) |
             (diabetes['Insulin'].isnull()) |
            (diabetes['BloodPressure'].isnull()) |
            (diabetes['Age'].isnull())]
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %%
diabetes.loc[(diabetes['Outcome']==0,'SkinThickness')]
# Out:
# 1      29
# 3      23
# 5       0
# 7       0
# 10      0
#        ..
# 762     0
# 763    48
# 764    27
# 765    23
# 767    31
# Name: SkinThickness, Length: 500, dtype: int64

# %%
averageSkinThickness=diabetes.loc[(diabetes['Outcome']==0,'SkinThickness')].mean()
diabetes.loc[diabetes['SkinThickness']==0,'SkinThickness'] = averageSkinThickness
# Out:
# C:\Users\15288\AppData\Local\Temp\ipykernel_10612\2620703149.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '19.664' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   diabetes.loc[diabetes['SkinThickness']==0,'SkinThickness'] = averageSkinThickness

# %%
diabetes.loc[(diabetes['Outcome'] == 1) &
              (diabetes['SkinThickness'] == averageSkinThickness)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 2              8      183             64         19.664        0  23.3
# 9              8      125             96         19.664        0   0.0
# 11            10      168             74         19.664        0  38.0
# 15             7      100              0         19.664        0  30.0
# 17             7      107             74         19.664        0  29.6
# ..           ...      ...            ...            ...      ...   ...
# 749            6      162             62         19.664        0  24.3
# 750            4      136             70         19.664        0  31.2
# 757            0      123             72         19.664        0  36.3
# 759            6      190             92         19.664        0  35.5
# 766            1      126             60         19.664        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 2                       0.672   32        1
# 9                       0.232   54        1
# 11                      0.537   34        1
# 15                      0.484   32        1
# 17                      0.254   31        1
# ..                        ...  ...      ...
# 749                     0.178   50        1
# 750                     1.182   22        1
# 757                     0.258   52        1
# 759                     0.278   66        1
# 766                     0.349   47        1
#
# [88 rows x 9 columns]

# %%
clean_data=pd.read_csv(r'E:\糖尿病\糖尿病\diabetes.csv')

# %%
clean_data.loc[clean_data['Outcome']== 2,'Outcome'] = 1
averageBloodPressure=clean_data.loc[(clean_data['Outcome']==0,'BloodPressure')].mean()
clean_data.loc[clean_data['BloodPressure']==0,'BloodPressure'] = averageBloodPressure
averageSkinThickness=clean_data.loc[(clean_data['Outcome']==0,'SkinThickness')].mean()
clean_data.loc[clean_data['SkinThickness']==0,'SkinThickness'] = averageSkinThickness
averageInsulin=clean_data.loc[(clean_data['Outcome']==0,'Insulin')].mean()
clean_data.loc[clean_data['Insulin']==0,'Insulin'] = averageInsulin
averageBMI=clean_data.loc[(clean_data['Outcome']==0,'BMI')].mean()
clean_data.loc[clean_data['BMI']==0,'BMI'] = averageBMI
averageBloodPressure=clean_data.loc[(clean_data['Outcome']==1,'BloodPressure')].mean()
clean_data.loc[clean_data['BloodPressure']==0,'BloodPressure'] = averageBloodPressure
averageSkinThickness=clean_data.loc[(clean_data['Outcome']==1,'SkinThickness')].mean()
clean_data.loc[clean_data['SkinThickness']==0,'SkinThickness'] = averageSkinThickness
averageInsulin=clean_data.loc[(clean_data['Outcome']==1,'Insulin')].mean()
clean_data.loc[clean_data['Insulin']==0,'Insulin'] = averageInsulin
averageBMI=clean_data.loc[(clean_data['Outcome']==1,'BMI')].mean()
clean_data.loc[clean_data['BMI']==0,'BMI'] = averageBMI
# Out:
# C:\Users\15288\AppData\Local\Temp\ipykernel_10612\151181963.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '68.184' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   clean_data.loc[clean_data['BloodPressure']==0,'BloodPressure'] = averageBloodPressure
# C:\Users\15288\AppData\Local\Temp\ipykernel_10612\151181963.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '19.664' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   clean_data.loc[clean_data['SkinThickness']==0,'SkinThickness'] = averageSkinThickness
# C:\Users\15288\AppData\Local\Temp\ipykernel_10612\151181963.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '68.792' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   clean_data.loc[clean_data['Insulin']==0,'Insulin'] = averageInsulin

# %%
sb.pairplot(clean_data,hue='Outcome')

# %%
clean_data.mean()
# Out:
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                72.212812
# SkinThickness                26.348604
# Insulin                     113.299750
# BMI                          32.426623
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Outcome                       0.348958
# dtype: float64

# %%
clean_data.median()
# Out:
# Pregnancies                   3.0000
# Glucose                     117.0000
# BloodPressure                72.0000
# SkinThickness                23.0000
# Insulin                      68.7920
# BMI                          32.0000
# DiabetesPedigreeFunction      0.3725
# Age                          29.0000
# Outcome                       0.0000
# dtype: float64

# %%
clean_data.mode()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          1.0       99           70.0         19.664   68.792  32.0
# 1          NaN      100            NaN            NaN      NaN   NaN
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.254  22.0      0.0
# 1                     0.258   NaN      NaN

# %%
plt.figure(figsize=(20, 20))

for column_index, column in enumerate(clean_data.columns):
    if column == 'Outcome':
        continue
    plt.subplot(4, 4, column_index + 1)
    sb.violinplot(x='Outcome', y=column, data=clean_data)

# %%
plt.figure(figsize=(20,20))

for column_index, column in enumerate(clean_data.columns):
    if column == 'Outcome':
        continue
    plt.subplot(4, 4, column_index + 1)
    sb.boxplot(x='Outcome', y=column, data=clean_data)
